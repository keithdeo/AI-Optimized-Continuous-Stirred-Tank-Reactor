# %%
import pandas as pd

data = pd.read_csv('reaction_data_copy.csv')

print(data.head())
print(data.shape)
print(data.describe())
# Out:
#    Temperature (K)  Concentration (M)   Time (s)  Reaction Rate  \
# 0       592.828203           3.344053  49.677145       0.298638
# 1       529.205347           2.171399  42.089633       0.027551
# 2       540.043368           3.061813  55.123938       0.055957
# 3       581.663921           3.767659  43.688093       0.246402
# 4       505.520098           2.856833  53.589601       0.015463
#
#    Conversion A to B  Remainder A  Product B
# 0           0.988161     0.039590   3.304464
# 1           0.413770     1.272939   0.898461
# 2           0.634846     1.118035   1.943779
# 3           0.942569     0.216381   3.551278
# 4           0.251788     2.137517   0.719316
# (10000, 7)
#        Temperature (K)  Concentration (M)      Time (s)  Reaction Rate  \
# count     10000.000000       10000.000000  10000.000000   10000.000000
# mean        500.753866           2.998621     49.985309       0.054880
# std          57.459292           0.582141      5.765671       0.082152
# min         400.037864           2.000044     40.002262       0.000075
# 25%         451.219436           2.487532     44.941194       0.001601
# 50%         500.412875           3.003268     50.098789       0.013314
# 75%         550.083494           3.506987     54.922499       0.075358
# max         599.985429           3.999483     59.997211       0.422038
#
#        Conversion A to B   Remainder A     Product B
# count       10000.000000  10000.000000  10000.000000
# mean            0.361692      1.912041      1.086580
# std             0.364222      1.169366      1.135107
# min             0.001471      0.004954      0.003436
# 25%             0.026425      0.849610      0.078625
# 50%             0.199653      2.101632      0.590328
# 75%             0.715136      2.863164      2.020872
# max             0.998117      3.983970      3.986023

# %%
import matplotlib.pyplot as plt

plt.scatter(data['Temperature (K)'], data['Conversion A to B'])
plt.xlabel('Temperature (K)')
plt.ylabel('Conversion A to B')
plt.title('Conversion A to B vs Temperature')
plt.show()
